# %%
import os
from tkinter import *
import sqlite3
import datetime
import time
from PIL import ImageTk, Image


def register():
    global root
    root = Toplevel(main)
    root.geometry('900x1000') #it is for window size
    root.configure(bg="#FFCCFF")
    root.title("Registration Form")
    

    
    label_update = Label(root, text="Enter Basic Information",width=20,font=('arial',30,'bold'),fg="Steel Blue",bd=20,bg="#FFCCFF",anchor='w')  # titile of page
    label_update.place(x=180,y=10)
    
    global Fullname
    global var_1
    global var
    global Phone
    global location
    global entry_1
    global entry_2
    global entry_4
    global entry_5
    
    Fullname=StringVar()
    var = IntVar()#farmer,agent,shop registration
    var_1 = IntVar() #gender
    Phone = StringVar()
    location = StringVar()
    
    
    label_1 = Label(root, text="Department :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') # department title
    label_1.place(x=180,y=180)
    
    Farmer= Radiobutton(root, text="Farmer",padx = 5,font=('arial',15,'bold'),bg="#FFCCFF",variable=var, value=1).place(x=325,y=180)
    Agent= Radiobutton(root, text="Agent",padx = 5,font=('arial',15,'bold'),bg="#FFCCFF",variable=var, value=2).place(x=425,y=180)
    Agro_shop_ower= Radiobutton(root, text="Agriculture Shop Owner",padx = 5,font=('arial',15,'bold'),bg="#FFCCFF",variable=var, value=3).place(x=525,y=180)

    
    label_1 = Label(root, text="FullName :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') #FullName title
    label_1.place(x=180,y=280)

    entry_1 = Entry(root,textvar=Fullname,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white') # entry of fullname
    entry_1.place(x=350,y=280)

    label_2 = Label(root, text="Phone no :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') #phone no title
    label_2.place(x=180,y=380)

    entry_2 = Entry(root,textvar=Phone,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  # entry of phone
    entry_2.place(x=350,y=380)

    label_3 = Label(root, text="Gender :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') #FullName Gender
    label_3.place(x=180,y=480)

    Male= Radiobutton(root, text="Male",padx = 5,font=('arial',15,'bold'),bg="#FFCCFF",variable=var_1, value=1).place(x=350,y=480)
    Female= Radiobutton(root, text="Female",padx = 5,font=('arial',15,'bold'),bg="#FFCCFF",variable=var_1, value=2).place(x=450,y=480)
    
    label_4 = Label(root, text="Location :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') #location title
    label_4.place(x=180,y=580)

    entry_4 = Entry(root,textvar=location,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  # entry of location
    entry_4.place(x=350,y=580)

    Button(root, text='submit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=6).place(x=340,y=700) # calling a clear() function
    Button(root, text='Quit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=6,command=root.destroy).place(x=500,y=700) # quiting a page
    
    
def languages():
    global root1
    root1= Toplevel(main)
    root1.geometry("150x50")
    root1.configure(bg="#FFCCFF")
    
    menu = StringVar()
    menu.set("Secelt Any Language")
    drop = OptionMenu (root1,menu,"SELECT","English","Hindi","Kannada","Marathi","Tamil","Telugu","Malayalam")
    drop.pack()
    
def crops():
    global root2
    root2 = Toplevel(main)
    root2.geometry("600x650")
    root2.configure(bg="#FFCCFF")
    
    label_up = Label(root2, text="Crop Information",width=20,font=('arial',20,'bold'),fg="Steel Blue",bd=20,bg="#FFCCFF",anchor='w')# titile of page
    label_up.place(x=200,y=30)
    
    def kharif_crop():
        global main1
        global strng
       
        main1 = Toplevel(root2)
        main1.geometry("1150x500")
        label_k = Label(main1, font=('arial',30,'bold'),text="Kharif Crop Details",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
        label_k.place(x=400,y=10)
        
        strng="The Kharif season varies by crop and region.\n starting at the earliest in May and ending at the latest in January.\n In India, the season is popularly considered to start in June and end in October.\n Kharif crops are usually sown at the beginning of the first rains during the advent of the south-west monsoon season\n and they are harvested at the end of monsoon season (October–November).\n common kharif crops are Jowar, Maize, Millet, Rice.\n"
        label_k1 = Label(main1,font=('arial',15,'bold'),text=strng,fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k1.place(x=0,y=200)
        
        
    def Rabi_crop():
        global main2
        global strng1
       
        main2 = Toplevel(root2)
        main2.geometry("1000x500")
        label_k2 = Label(main2, font=('arial',30,'bold'),text="Rabi Crop Details",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
        label_k2.place(x=300,y=10)
        
        strng1 = "Rabi crops are sown around mid-November.\n preferably after the monsoon rains are over, and harvesting begins in April / May.\n The crops are grown either with rainwater that has percolated into the ground or using irrigation.\n Good rain in winter spoils rabi crops.\n The major rabi crop in India is wheat, followed by barley, mustard, sesame and peas.\n Peas are harvested early, as they are ready early,\n Indian markets are flooded with green peas from January to March, peaking in February.\n"        
        label_k3 = Label(main2,font=('arial',15,'bold'),text=strng1,fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k3.place(x=0,y=200)
        
        
    def Zaid_crop():
        global main3
        global strng2
       
        main3 = Toplevel(root2)
        main3.geometry("1200x500")
        label_k4 = Label(main3, font=('arial',30,'bold'),text="Zaid Crop Details",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
        label_k4.place(x=300,y=10)
        
        strng2= "Zaid crops are summer season crops.\n They grow for a short time period between Kharif and Rabi crops, mainly from March to June.\n These crops are mainly grown in the summer season during a period called the Zaid crop season.\n They require warm dry weather as major growth period and longer day length for flowering.\n Some summer months and rainy season is required.\n These crops also mature early.\n In between the Rabi and the Kharif seasons, there is a short season during the summer months known as the Zaid season.\n Some of the crops produced during Zaid season are watermelon, muskmelon, cucumber, vegetables and fodder crops.\n Sugarcane takes almost a year to grow."    
        label_k5 = Label(main3,font=('arial',15,'bold'),text=strng2,fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k5.place(x=0,y=150)


    Button(root2, text='Kharif',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#6699FF",width=8,command= kharif_crop).place(x=250,y=150) 
    Button(root2, text='Rabi',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#6699FF",width=8,command= Rabi_crop).place(x=250,y=250) 
    Button(root2, text='Zaid',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#6699FF",width=8,command=Zaid_crop).place(x=250,y=350) 
    Button(root2, text='Quit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=8,command=root2.destroy).place(x=250,y=450) # quiting a page

def crop_diseases():
    global root3
    root3 = Toplevel(main)
    root3.geometry("600x600")
    root3.configure(bg="#FFCCFF")
    
    label_k6 = Label(root3, font=('arial',20,'bold'),text="Crop Disease Details",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
    label_k6.place(x=100,y=10)
    
    def fungal_dis():
        global main4
        global strng3
        main4 = Toplevel(root3)
        main4.geometry("1400x500")
        label_k7 = Label(main4, font=('arial',20,'bold'),text="Fungal Diseases Details",fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k7.place(x=500,y=10)
        
        strng3 = "Fungi constitute the largest number of plant pathogens and are responsible for a range of serious plant diseases.\n Most vegetable diseases are caused by fungi.\n They damage plants by killing cells and/or causing plant stress.\n Sources of fungal infections are infected seed, soil, crop debris, nearby crops and weeds.\n Fungi are spread by wind and water splash, and through the movement of \n contaminated soil, animals, workers, machinery, tools, seedlings and other plant material.\n They enter plants through natural openings such as stomata and through wounds caused by \n pruning, harvesting, hail, insects, other diseases, and mechanical damage.\n Some of the fungi are responsible for foliar diseases –\n Downy mildews; Powdery mildews; and White blister are some of the highly prevalent foliar diseases.\n Other fungi – Clubroot; Pythium species; Fusarium species; Rhizoctonia species; Sclerotinia and Sclerotium species – are soilborne diseases."        
        label_k8 = Label(main4,font=('arial',15,'bold'),text=strng3,fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k8.place(x=0,y=100)
        
        
    def bact_dis():
        
        global main5
        global strng4
       
        main5 = Toplevel(root3)
        main5.geometry("1500x500")
        label_k9 = Label(main5, font=('arial',20,'bold'),text="Bacterial Diseases Details",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
        label_k9.place(x=500,y=10)
        
        strng4= "Bacterial diseases can be grouped into four broad categories based on \n the extent of damage to plant tissue and the symptoms that they cause,\n which may include vascular wilt, necrosis, soft rot, and tumours.\n Vascular wilt results from the bacterial invasion of the plant’s vascular system.\n Drooping, wilting, or death of the aerial plant structure may occur;\n examples include bacterial wilt of sweet corn, alfalfa, tobacco, tomato, and cucurbits (e.g., squash, pumpkin, and cucumber) and black rot of crucifers.\n Pathogens can cause necrosis by secreting a toxin (poison).\n Symptoms include formation of leaf spots, stem blights, or cankers."        
        label_k10 = Label(main5,font=('arial',15,'bold'),text=strng4,fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k10.place(x=0,y=150)
        
    def viral_dis():
        global main6
        global strng5
       
        main6 = Toplevel(root3)
        main6.geometry("1500x500")
        label_k11 = Label(main6, font=('arial',20,'bold'),text="Viral Diseases Details",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
        label_k11.place(x=500,y=10)
        
        strng5 = "The details of plant virus replication are complex and beyond the scope of this fact sheet,\n the general idea is that plant viruses cause disease in part by \n causing a reallocation of photosynthates and a disruption of normal cellular processes as they replicate.\n Interestingly, many kinds of plants are infected with viruses and show no symptoms.\n Such infections are referred to as being latent.\n Some viruses, such as cucumber mosaic virus (CMV) and cowpea mosaic virus (CPMV),\n occur as a complex of multiple component particles, each containing different nucleic acid cores.\n In multi-component viruses, all components have to be present in a plant for infection and replication to take place. \n Viruses are difficult to classify and, for lack of anything better,\n they were given descriptive (and sometimes colorful) names based on the disease they cause—for example,\n tobacco ring spot, watermelon mosaic, barley yellow dwarf, potato mop top, citrus tristeza, sugar beet curly top, lettuce mosaic, maize dwarf mosaic,\n potato leaf roll, peach yellow bud mosaic, African cassava mosaic, carnation streak, and tomato spotted wilt.\n"        
        label_k12 = Label(main6,font=('arial',15,'bold'),text=strng5,fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
        label_k12.place(x=0,y=100)
        
        
    Button(root3, text='Fungal',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#6699FF",width=8,command= fungal_dis).place(x=250,y=150)
    Button(root3, text='Bacterial',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#6699FF",width=8,command= bact_dis).place(x=250,y=250) 
    Button(root3, text='Viral',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#6699FF",width=8,command=viral_dis).place(x=250,y=350) 
    Button(root3, text='Quit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=8,command=root3.destroy).place(x=250,y=450) # quiting a page

def agro_store():
    global root4
    global Storename
    global entry_5
    global phn
    global entry_6
    global loc
    global entry_7
    global str_lic
    global entry_8
    
    Storename=StringVar()
    Phn = StringVar()
    loc = StringVar()
    str_lic = StringVar()
    
    root4 = Toplevel(main)
    root4.geometry("850x600")
    root4.configure(bg="#FFCCFF")
    
    label_k13 = Label(root4, font=('arial',20,'bold'),text="Agriculture Store Registration",fg="#9900CC",bd=10,bg="#FFCCFF",anchor='w')
    label_k13.place(x=200,y=10)
    
    label_5 = Label(root4, text="Store Name :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') 
    label_5.place(x=180,y=100)

    entry_5 = Entry(root4,textvar=Storename,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white') 
    entry_5.place(x=350,y=100)

    label_6 = Label(root4, text="Phone No :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') 
    label_6.place(x=180,y=200)

    entry_6 = Entry(root4,textvar=Phn,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  
    entry_6.place(x=350,y=200)

    label_7 = Label(root4, text="Location :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w')
    label_7.place(x=180,y=300)

    entry_7 = Entry(root4,textvar=loc,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  
    entry_7.place(x=350,y=300)
    
    label_8 = Label(root4, text="Store Licence No :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') 
    label_8.place(x=180,y=400)

    entry_8 = Entry(root4,textvar=str_lic,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  
    entry_8.place(x=350,y=400)

    Button(root4, text='submit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=6).place(x=340,y=500)  
    Button(root4, text='Quit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=6,command=root4.destroy).place(x=500,y=500) # quiting a page
    

def agro_agent():
    global root5
    global Agentname
    global entry_9
    global phn1
    global entry_10
    global loc1
    global entry_11
    global agent_lic_no
    global entry_12
    
    Agentname=StringVar()
    Phn1 = StringVar()
    loc1 = StringVar()
    agent_lic_no = StringVar()
    
    root5 = Toplevel(main)
    root5.geometry("850x600")
    root5.configure(bg="#FFCCFF")
    
    label_k14 = Label(root5, font=('arial',20,'bold'),text="Agent Registration",fg="#9900CC",bd=10, bg="#FFCCFF",anchor='w')
    label_k14.place(x=200,y=10)
    
    label_9 = Label(root5, text="Agent Name :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') 
    label_9.place(x=180,y=100)

    entry_9 = Entry(root5,textvar=Agentname,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white') 
    entry_9.place(x=350,y=100)

    label_10 = Label(root5, text="Phone No :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') 
    label_10.place(x=180,y=200)

    entry_10 = Entry(root5,textvar=Phn1,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  
    entry_10.place(x=350,y=200)

    label_11 = Label(root5, text="Location :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w')
    label_11.place(x=180,y=300)

    entry_11 = Entry(root5,textvar=loc1,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  
    entry_11.place(x=350,y=300)
    
    label_12 = Label(root5, text="Agent Licence No :",width=20,font=("bold", 15),bg="#FFCCFF",anchor='w') 
    label_12.place(x=180,y=400)

    entry_12 = Entry(root5,textvar=agent_lic_no,bd=8,insertwidth=4,bg="#6699FF",justify='left',font=('arial',15,'bold'),fg='white')  
    entry_12.place(x=350,y=400)

    Button(root5, text='submit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=6).place(x=340,y=500)  
    Button(root5, text='Quit',padx=8,pady=8,bd=8,fg="black",font=('arial',12,'bold'),bg="#FFCC99",width=6,command=root5.destroy).place(x=500,y=500) # quiting a page
    

main=Tk()
# to change the size of the window
main.geometry('1500x1000')
main.configure(bg="#99CC00")

# to write the text
label = Label(main, font=('arial',30,'bold'),text="Agriculture_helP",fg="#9900CC",bd=10, bg="#33FFFF",anchor='w')
label.place(x=550,y=10)

localtime=time.asctime(time.localtime(time.time()))
lblInfo=Label(main,font=('arial',20,'bold'),text=localtime,fg="#6633FF",bd=10,anchor='w')
lblInfo.grid(row=1,column=0)


Button(main, text='REGISTRATION',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#FFCCFF",width=10,command=register).place(x=500,y=140)
Button(main, text='SELECT LANGUAGE',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#FFCCFF",width=15,command=languages).place(x=700,y=140)
Button(main, text='TYPES OF CROPS',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#FFCC99",width=20,command=crops).place(x=600,y=270)
Button(main, text='CROP DISEASES',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#FFCC99",width=20,command=crop_diseases).place(x=600,y=370)    
Button(main, text='AGRICULTURE STORES',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#FFCC99",width=20,command= agro_store).place(x=600,y=470)
Button(main, text='AGRICULTURE AGENTS',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#FFCC99",width=20,command= agro_agent).place(x=600,y=570)
Button(main, text='Quit',padx=16,pady=8,bd=12,fg="black",font=('arial',15,'bold'),bg="#6699FF",width=10,command=main.destroy).place(x=650,y=700)
main.mainloop()
